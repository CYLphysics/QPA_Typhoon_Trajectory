# %%
import matplotlib.pyplot as plt 
import numpy as np 
import os
import sys

current_dir = os.getcwd()
sys.path.append(os.path.dirname(current_dir))

# %%
## classical full model
    
num_p_classical_full = [8399540]
total_avg_err_classical_full = [144.77758425091363]

## classical pruning 
# 09, 07, 05, 03, 01 
num_p_classical_pruning = [
                          840472,
                          2519872,
                          4199468,
                          5879000,
                          7558399
                          ]
total_avg_err_classical_pruning = [
                                    295.14519357079485,
                                    170.8696957793443,
                                    179.92124192968166,
                                    143.14913042250475,
                                    148.63388165463002
                                  ] 

## classical weight sharing
# 
num_p_classical_ws = [  1093556,
                        1867700,
                        2641844,
                        3415988,
                        4190132,
                        4964276,
                    
                        ]

total_avg_err_classical_ws = [
                             195.93910269106732,
                             150.2697455817865,
                             156.56363540148683,
                             145.67171934538683,
                             151.42156092005217,
                             148.69654630383644,
                             
                            ]

# QPA
# chunk_size (n_{mlp} in report) = 32, 64, 129, 256, 512, 768 
# qubit count = 9, 8, 7, 6, 5, 4
num_p_QPA_diff_chs = [
    212926,
    215774,
    224006,
    240558,
    273750,
    306986
] 
total_avg_QPA_diff_chs = [
    163.48510424914085,
    170.0416312202111,
    168.77113862133933,
    186.0051786285219,
    157.46179065034156,
    162.87378983724307
]

# QNN depth = 4, 8, 12 ,16, 20
num_p_QPA_chs_64_diff_qnn_depth =[
    215774,
    215930,
    216086,
    216242,
    216398,
]

total_avg_QPA_chs_64_diff_chs = [
    170.0416312202111,
    183.46241987996524,
    189.32798096192232,
    171.1740982811834,
    153.13541450781142
]

num_p_QPA_chs_768_diff_qnn_depth = [
    306986,
    307058,
    307130,
    307202,
    307274
]

total_avg_QPA_chs_768_diff_chs = [
    162.87378983724307,
    178.18016255534022,
    150.20430670549536,
    168.59556903370486,
    151.66109712570176
]

# %%
import matplotlib.ticker as mticker
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset


plt.figure(figsize=(5.5, 3), dpi = 300)
fig, ax = plt.subplots(figsize=(6, 3), dpi = 300)
plt.title("Typhoon Trajectory Forecasting\non Testing Dataset (2015-2018)")


lw = 0.5 

ax.plot(
    num_p_classical_full,
    total_avg_err_classical_full,
    label = "classical full model", color = plt.cm.magma(0.70),
    markersize = 10,
    marker = "*", lw = 1, markerfacecolor=plt.cm.magma(0.90),
    alpha = 0.85
    )

ax.plot(
    num_p_QPA_diff_chs,#[:-1],
    total_avg_QPA_diff_chs,
    label = "QPA", color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4
    )

ax.plot(
    num_p_QPA_chs_64_diff_qnn_depth,#[:-1],
    total_avg_QPA_chs_64_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4
    )

ax.plot(
    num_p_QPA_chs_768_diff_qnn_depth,#[:-1],
    total_avg_QPA_chs_768_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4
    )

ax.plot(
    num_p_classical_ws,
    total_avg_err_classical_ws,
    label = "weight sharing", color = plt.cm.magma(0.12),
    marker = "^", lw = 1, markerfacecolor=plt.cm.magma(0.25),
    alpha = 0.85
    )

ax.plot(
    num_p_classical_pruning,
    total_avg_err_classical_pruning,
    label = "pruning", color = plt.cm.magma(0.55),
    marker = "o", lw = 1, markerfacecolor=plt.cm.magma(0.65),
    alpha = 0.85
    )





ax_inset = inset_axes(ax, width="46%", height="30%",
                      bbox_to_anchor=(0.6, 0.18, 1., 1.9),  # (x, y, width, height)
                      bbox_transform=ax.transAxes,  
                      loc="lower right")  # Inset size and location


ax_inset.plot(
    num_p_classical_full,
    total_avg_err_classical_full,
    label = "classical target", color = plt.cm.magma(0.70),
    markersize = 10,
    marker = "*", lw = 1, markerfacecolor=plt.cm.magma(0.90),
    alpha = 0.85
    )

ax_inset.plot(
    num_p_QPA_diff_chs,#[:-1],
    total_avg_QPA_diff_chs,
    label = "QPA", color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4
    )
ax_inset.plot(
    num_p_QPA_chs_64_diff_qnn_depth,#[:-1],
    total_avg_QPA_chs_64_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4
    )
ax_inset.plot(
    num_p_QPA_chs_768_diff_qnn_depth,#[:-1],
    total_avg_QPA_chs_768_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4
    )
ax_inset.plot(
    num_p_classical_ws,
    total_avg_err_classical_ws,
    label = "weight sharing", color = plt.cm.magma(0.12),
    marker = "^", lw = 1, markerfacecolor=plt.cm.magma(0.25),
    alpha = 0.85
    )

ax_inset.plot(
    num_p_classical_pruning,
    total_avg_err_classical_pruning,
    label = "pruning", color = plt.cm.magma(0.55),
    marker = "o", lw = 1, markerfacecolor=plt.cm.magma(0.65),
    alpha = 0.85
    )

# Set limits for zoomed region
ax_inset.set_xlim(2e5, 3.3e5)
ax_inset.set_ylim(140, 200)
ax_inset.set_xscale('log')
# ax_inset.grid(True, lw = 0.5)    

# Optional: Add zoom connector lines
# mark_inset(ax, ax_inset, loc1=4, loc2=2, fc="none", ec="0.5", alpha = 0.2)

ax.set_ylabel("Total Avg. Error (km)")
ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax.set_xlabel("# Trainable Parameters")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.legend(fontsize = 11) #, bbox_to_anchor = (1.47, 0.78))
ax.grid(True, lw = 0.5)    
# ax.set_tight_layout(rect=[0, 0, 1, 0.94])

# plt.tight_layout()
plt.savefig("../results/plots/quantum_vs_classical_result_plot.png", bbox_inches="tight")  # Save as a PDF
plt.show()

# %%
import matplotlib.ticker as mticker
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset


plt.figure(figsize=(10, 2), dpi = 300)
# fig, ax = plt.subplots(figsize=(6, 3), dpi = 300)
# plt.title("Typhoon Trajectory Forecasting\non Testing Dataset (2015-2018)")


plt.subplot(1,3,1)
lw = 0.5 

plt.plot(
    num_p_QPA_diff_chs,#[:-1],
    total_avg_QPA_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4,
    label = "$L = 4$"
    )
# plt.text(215760, 185, "(b)", size = 12, fontweight = "bold")


plt.ylabel("Total Avg. Error (km)")
# plt..ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel("# Trainable Parameters")

plt.grid(True, lw = 0.5)

plt.legend()

plt.subplot(1,3,2)

plt.plot(
    num_p_QPA_chs_64_diff_qnn_depth,#[:-1],
    total_avg_QPA_chs_64_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4,
    label = "$n_{mlp} = 64$"
    )
plt.grid(True, lw = 0.5)
plt.xlabel("# Trainable Parameters")
# plt.text(215760, 188, "(b)", size = 12, fontweight = "bold")

plt.legend()

plt.subplot(1,3,3)
plt.plot(
    num_p_QPA_chs_768_diff_qnn_depth,#[:-1],
    total_avg_QPA_chs_768_diff_chs,
    color = plt.cm.magma(0.35),
    marker = "s", lw = 1, markerfacecolor=plt.cm.magma(0.45),
    alpha = 0.85 , zorder = 4,
    label = "$n_{mlp} = 768$"
    
    )
# plt.text(306980, 177, "(c)", size = 12, fontweight = "bold")
plt.legend()
# Optional: Add zoom connector lines
# mark_inset(ax, ax_inset, loc1=4, loc2=2, fc="none", ec="0.5", alpha = 0.2)

# ax.set_xscale('log')
# ax.set_yscale('log')
plt.grid(True, lw = 0.5)    
# ax.set_tight_layout(rect=[0, 0, 1, 0.94])
plt.xlabel("# Trainable Parameters")

plt.tight_layout()
plt.savefig("../results/plots/QPA_hyperparameters_investigation.png", bbox_inches="tight")  # Save as a PDF
plt.show()
